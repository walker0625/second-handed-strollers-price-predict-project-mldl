# %% [markdown]
# # Clean 데이터 학습
# ## 결측치가 없는(모델, 상태, 지역 정보가 모두 있는) 데이터로 회귀 모델 학습

# %% [markdown]
# ### 1. 결측치가 없는 데이터로 변환

# %% [markdown]
# ### 2. 데이터 벡터화(이미지s + 모델 + 상태 + 지역)

# %% [markdown]
# ### 3. 벡터화된 데이터로 모델 학습
